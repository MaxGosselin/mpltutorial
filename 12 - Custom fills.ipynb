# %% [markdown]
# # 6 - Charting Data from the internet
#
# Following the matplotlib tutorial by sentdex.
#
# Link: https://www.youtube.com/watch?v=q7Bo_J8x_dw&list=PLQVvvaa0QuDfefDfXb9Yf0la1fPDKluPF

# %%
get_ipython().run_line_magic('matplotlib', 'inline')

import matplotlib.pyplot as plt
import numpy as np

import urllib
import matplotlib.dates as mdates

# %% [markdown]
# #### Let's have a look at AAPL

# %%
def bytespdate2num(fmt, encoding='utf-8'):
    strconverter = mdates.strpdate2num(fmt)
    def bytesconverter(b):
        s = b.decode(encoding)
        return strconverter(s)
    return bytesconverter

def graph_data():
    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    plt.plot_date(date, closep, '-')
        
    plt.xlabel('date')
    plt.ylabel('price')
    plt.title('Interesting graph\nCheck it out')
    plt.legend()
    plt.show()

graph_data()
# Out:
# No handles with labels found to put in legend.

# %%
650/28
# Out:
# 23.214285714285715

# %% [markdown]
# # 6 - Charting Data from the internet
#
# Following the matplotlib tutorial by sentdex.
#
# Link: https://www.youtube.com/watch?v=q7Bo_J8x_dw&list=PLQVvvaa0QuDfefDfXb9Yf0la1fPDKluPF

# %%
get_ipython().run_line_magic('matplotlib', 'inline')

import matplotlib.pyplot as plt
import numpy as np

import urllib
import matplotlib.dates as mdates

# %% [markdown]
# #### Let's have a look at AAPL

# %%
def bytespdate2num(fmt, encoding='utf-8'):
    strconverter = mdates.strpdate2num(fmt)
    def bytesconverter(b):
        s = b.decode(encoding)
        return strconverter(s)
    return bytesconverter

def graph_data():
    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    plt.plot_date(date, closep, '-')
        
    plt.xlabel('date')
    plt.ylabel('price')
    plt.title('Interesting graph\nCheck it out')
    plt.legend()
    plt.show()

graph_data()
# Out:
# No handles with labels found to put in legend.

# %%
def bytespdate2num(fmt, encoding='utf-8'):
    strconverter = mdates.strpdate2num(fmt)
    def bytesconverter(b):
        s = b.decode(encoding)
        return strconverter(s)
    return bytesconverter

def graph_data():
    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    plt.plot_date(date, closep, '-')
    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')
   
    plt.xlabel('date')
    plt.ylabel('price')
    plt.title('Interesting graph\nCheck it out')
    plt.legend()
    plt.show()

graph_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1d1d897e8c63> in <module>
#      40     plt.show()
#      41
# ---> 42 graph_data()
#      43
#
# <ipython-input-6-1d1d897e8c63> in graph_data()
#      25                                                                      converters={0: bytespdate2num('%Y-%m-%d')})
#      26     plt.plot_date(date, closep, '-')
# ---> 27     for label in ax1.xaxis.get_ticklabels():
#      28         label.set_rotation(45)
#      29
#
# NameError: name 'ax1' is not defined

# %% [markdown]
# # 6 - Charting Data from the internet
#
# Following the matplotlib tutorial by sentdex.
#
# Link: https://www.youtube.com/watch?v=q7Bo_J8x_dw&list=PLQVvvaa0QuDfefDfXb9Yf0la1fPDKluPF

# %%
get_ipython().run_line_magic('matplotlib', 'inline')

import matplotlib.pyplot as plt
import numpy as np

import urllib
import matplotlib.dates as mdates

# %% [markdown]
# #### Let's have a look at AAPL

# %%
def bytespdate2num(fmt, encoding='utf-8'):
    strconverter = mdates.strpdate2num(fmt)
    def bytesconverter(b):
        s = b.decode(encoding)
        return strconverter(s)
    return bytesconverter

def graph_data():
    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))


    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    plt.plot_date(date, closep, '-')
    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')
   
    plt.xlabel('date')
    plt.ylabel('price')
    plt.title('Interesting graph\nCheck it out')
    plt.legend()
    plt.show()

graph_data()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
import numpy as np

import urllib
import matplotlib.dates as mdates

# %%
def bytespdate2num(fmt, encoding='utf-8'):
    strconverter = mdates.strpdate2num(fmt)
    def bytesconverter(b):
        s = b.decode(encoding)
        return strconverter(s)
    return bytesconverter

# %%
def graph_data():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    ax1.plot_date(date, closep, '-', label='Price')

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()

# %%
graph_data()

# %%
def graph_fill_between():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.graph_fill_between(date, closep, 0)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()

# %%
graph_fill_between()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-96c79695aa25> in <module>
#       1 #%%
# ----> 2 graph_fill_between()
#
# <ipython-input-12-61cd06589fd4> in graph_fill_between()
#      22                                                                      converters={0: bytespdate2num('%Y-%m-%d')})
#      23     #ax1.plot_date(date, closep, '-', label='Price')
# ---> 24     ax1.graph_fill_between(date, closep, 0)
#      25
#      26     for label in ax1.xaxis.get_ticklabels():
#
# AttributeError: 'AxesSubplot' object has no attribute 'graph_fill_between'

# %%
def graph_fill_between():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.fill_between(date, closep, 0)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()

# %%
graph_fill_between()
# Out:
# No handles with labels found to put in legend.

# %%
def graph_fill_between_start():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.fill_between(date, closep, closep[0], 0.25)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()

# %%
graph_fill_between()
# Out:
# No handles with labels found to put in legend.

# %%
graph_fill_between_start()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-8f0e22d6fc49> in <module>
#       1 #%%
# ----> 2 graph_fill_between_start()
#
# <ipython-input-16-528d5890c757> in graph_fill_between_start()
#      22                                                                      converters={0: bytespdate2num('%Y-%m-%d')})
#      23     #ax1.plot_date(date, closep, '-', label='Price')
# ---> 24     ax1.fill_between(date, closep, closep[0], 0.25)
#      25
#      26     for label in ax1.xaxis.get_ticklabels():
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5057             where = True
#    5058         where = where & ~functools.reduce(np.logical_or,
# -> 5059                                           map(np.ma.getmask, [x, y1, y2]))
#    5060
#    5061         x, y1, y2 = np.broadcast_arrays(np.atleast_1d(x), y1, y2)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
def graph_fill_between_start():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.fill_between(date, closep, closep[0], alpha=0.25)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()

# %%
graph_fill_between_start()
# Out:
# No handles with labels found to put in legend.

# %%
def graph_fill_between_start():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.fill_between(date, closep, closep[0], alpha=0.85)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()

# %%
graph_fill_between_start()
# Out:
# No handles with labels found to put in legend.

# %%
def graph_fill_between_condition():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.fill_between(date, closep, closep[0],, where=(closep>closep[0]) alpha=0.85)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()
# Out:
#   File "<ipython-input-23-51ebbacb2ff5>", line 24
#     ax1.fill_between(date, closep, closep[0],, where=(closep>closep[0]) alpha=0.85)
#                                              ^
# SyntaxError: invalid syntax

# %%
# This time we graph the area between the first closing price and the rest.
graph_fill_between_condition()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-a400c1970078> in <module>
#       2
#       3 # This time we graph the area between the first closing price and the rest.
# ----> 4 graph_fill_between_condition()
#
# NameError: name 'graph_fill_between_condition' is not defined

# %%
def graph_fill_between_condition():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.fill_between(date, closep, closep[0],, where=(closep>closep[0]) alpha=0.85)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()
# Out:
#   File "<ipython-input-25-51ebbacb2ff5>", line 24
#     ax1.fill_between(date, closep, closep[0],, where=(closep>closep[0]) alpha=0.85)
#                                              ^
# SyntaxError: invalid syntax

# %%
# This time we graph the area between the first closing price and the rest.
graph_fill_between_condition()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a400c1970078> in <module>
#       2
#       3 # This time we graph the area between the first closing price and the rest.
# ----> 4 graph_fill_between_condition()
#
# NameError: name 'graph_fill_between_condition' is not defined

# %%
def graph_fill_between_condition():

    fig = plt.figure()
    ax1 = plt.subplot2grid((1, 1), (0, 0))

    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    
    stock_data = []
    split_source = source_code.split('\n')
    
    for line in split_source:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'Volume' not in line:
                stock_data.append(line)
    
    date, openp, highp, lowp, closep, adjustedp, volume = np.loadtxt(stock_data,
                                                                     delimiter=',',
                                                                     unpack=True,
                                                                     converters={0: bytespdate2num('%Y-%m-%d')})
    #ax1.plot_date(date, closep, '-', label='Price')
    ax1.fill_between(date, closep, closep[0], where=(closep>closep[0]), alpha=0.85)

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    
    ax1.grid(True) #, color='g', linestyle='-')

    # We can change axis label colors by:
    ax1.xaxis.label.set_color('c')
    ax1.yaxis.label.set_color('r')

    # We can set custom ranges for our axes
    ax1.set_yticks([0,100, 200, 300, 400, 500, 600, 700])

    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('AAPL')
    plt.legend()
    plt.show()

# %%
# This time we graph the area between the first closing price and the rest.
graph_fill_between_condition()
# Out:
# No handles with labels found to put in legend.

# %%
# This time we graph only the positive area between the first closing price and the rest.
graph_fill_between_condition()
# Out:
# No handles with labels found to put in legend.
